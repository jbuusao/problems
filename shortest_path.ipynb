# %%
from lib.graph import MyGraph

graph_data = {
    'A': {'B': 5, 'C': 3},
    'B': {'D': 2},
    'C': {'D': 1, 'E': 4},
    'D': {'E': 1},
}
g = MyGraph(graph_data, size="3,3", rankdir="LR", directed=True)
g.display()

# %%
tree_data = {
    'root': ['B', 'C'],
    'C': ['D', 'E'],
}
g = MyGraph(tree_data, size="3,3", rankdir="TB", directed=True, labelled=False)
g.display()
