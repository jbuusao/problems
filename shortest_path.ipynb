# %%
from lib.graph import MyGraph

graph_data = {
    'A': {'B': 5, 'C': 3},
    'B': {'D': 2},
    'C': {'D': 1, 'E': 4},
    'D': {'E': 1},
}
g = MyGraph(graph_data, size="3,3", rankdir="LR", directed=True)
g.display()

# %%
graph_data = {
    'A': ['A1', 'A2'],
    'A1': ['B1', 'B2'],

}
g = MyGraph(graph_data, size="3,3", rankdir="TB", directed=True, labelled=False)
g.display()
